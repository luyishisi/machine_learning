# %%
from PIL import Image
import os
from pylab import *

# %%
pil_im = Image.open('1.png')

# %%
pil_im.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=300x128 at 0x7F856EAFD350>

# %%
pil_im.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=300x128 at 0x7F856EAFDB50>

# %%
def get_imlist(path):
    """ 返回目录中所有 JPG 图像的文件名列表 """
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]

# %%
get_imlist('./')
# Out:
# ['./1 .jpg']

# %%
pil_im.thumbnail((128,128)).save('1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9bc3a663ac9f> in <module>()
# ----> 1 pil_im.thumbnail((128,128)).save('1.png')
#
# NameError: name 'pil_im' is not defined

# %%
pil_im.resize((128,128)).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-207666f5f7f8> in <module>()
# ----> 1 pil_im.resize((128,128)).show()
#
# NameError: name 'pil_im' is not defined

# %%
ratio = 2
wide = int(pil_im.size[0]*ratio)
high =  int(pil_im.size[1]*ratio)
pil_im.resize((wide,high)).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-544b5589d5bb> in <module>()
#       1 ratio = 2
# ----> 2 wide = int(pil_im.size[0]*ratio)
#       3 high =  int(pil_im.size[1]*ratio)
#       4 pil_im.resize((wide,high)).show()
#
# NameError: name 'pil_im' is not defined

# %%
imshow(im)

# %%
x = [100,100,400,400]
y = [200,500,200,500]

# %%
plot(x,y,'r*')

# %%
plot(x[:2],y[:2])

# %%
show()

# %%
im = array(Image.open('2.png').convert('L'))

# %%
figure()
gray()
contour(im, origin='image')
axis('equal')
axis('off')
# Out:
# (0.0, 200.0, 0.0, 160.0)

# %%
figure()
hist(im.flatten(),50)
show()

# %%
import os,re,time,MySQLdb,MySQLdb.cursors,urllib2,random
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-1db770be713f> in <module>()
# ----> 1 import os,re,time,MySQLdb,MySQLdb.cursors,urllib2,random
#
# ImportError: No module named MySQLdb
