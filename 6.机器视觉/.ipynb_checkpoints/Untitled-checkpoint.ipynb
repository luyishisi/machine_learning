# %%
from PIL import Image

# %%
pil_im = Image.open('1.png')

# %%
pil_im.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=300x128 at 0x7F856EAFD350>

# %%
pil_im.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=300x128 at 0x7F856EAFDB50>

# %%
import os

# %%
def get_imlist(path):
    """ 返回目录中所有 JPG 图像的文件名列表 """
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]

# %%
get_imlist('./')
# Out:
# ['./1 .jpg']

# %%
pil_im.thumbnail((128,128)).save('1_1.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-124a49b2894d> in <module>()
# ----> 1 pil_im.thumbnail((128,128)).save('1_1.png')
#
# AttributeError: 'NoneType' object has no attribute 'save'

# %%
pil_im.resize((128,128)).show()

# %%
ratio = 2
wide = int(pil_im.size[0]*ratio)
high =  int(pil_im.size[1]*ratio)
pil_im.resize((wide,high)).show()

# %%
from pylab import *

# %%
im = array( Image.open('2.png'))

# %%
imshow(im)

# %%
x = [100,100,400,400]
y = [200,500,200,500]

# %%
plot(x,y,'r*')

# %%
plot(x[:2],y[:2])

# %%
show()

# %%
im = array(Image.open('1.png').convert('L'))

# %%
figure()
gray()
contour(im, origin='image')
axis('equal')
axis('off')
# Out:
# (0.0, 300.0, 0.0, 140.0)

# %%
figure()
hist(im.flatten(),128)
show()
